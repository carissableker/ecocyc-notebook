# %%
# %matplotlib inline

# %% [markdown]
# # EcoCyc neo4j graph
#
# Description here

# %% [markdown]
# ## Load modules
#
#    * [pandas](https://pandas.pydata.org/)
#    * [python-igraph](http://igraph.org/python/)
#    * [py2neo](http://py2neo.org/2.0/intro.html)
#    * [visJS2jupyter](https://ucsd-ccbb.github.io/visJS2jupyter/)

# %%
import pandas as pd
import igraph as ig
from py2neo import Graph, Node, Relationship
import visJS2jupyter.visJS_module

# %% [markdown]
# The following module is a custom script in /opt/bnv_tools

# %%
import biocyc_neo4j_viz as bnv

# %% [markdown]
# ## Access the graph
# See http://localhost:7474/browser/ for the neo4j interface.

# %%
graph = Graph(host="neo4j")

# %% [markdown]
# ## Query graph
#
# The graph can be queried using CYPHER in two ways:
#
# ### 1. py2neo
# Write CYPHER statements and recive a cursor back
#
# ### 2. bnv
# Select one or more of 'source', 'target' or 'edge' and recieve a pandas dataframe with these three columns
# filled.

# %%
# Using py2neo
a = graph.run("MATCH (a) WHERE a.name={x} RETURN a.id", x='3_ISOPROPYLMALDEHYDROG_CPLX').evaluate()
a
# Out:
# '3_ISOPROPYLMALDEHYDROG_CPLX'

# %%
# Using bnv
df = bnv.query_graph(graph, target="gene", edge="REGULATES")

# %%
print( df.shape)
df.head()
# Out:
# (77, 3)
#        source target       type
# 0  REG0-12735    pnp  REGULATES
# 1  REG0-12365   rluD  REGULATES
# 2  REG0-12171   ribB  REGULATES
# 3  REG0-11885   gdhA  REGULATES
# 4  REG0-11857   cirA  REGULATES

# %% [markdown]
# ## Turn a query result into an igraph graph

# %%
g = ig.Graph.TupleList(df.values, directed=True, edge_attrs="type")

# %%
g.vcount()
# Out:
# 144

# %% [markdown]
# ## Visualize using visJS2jupyter

# %%
nodes_dict, edges_dict = bnv.prepare_plot_igraph(g, scale=10)

# %%
# plot network
visJS2jupyter.visJS_module.visjs_network(nodes_dict,
                                         edges_dict, 
                                         node_size_multiplier=30,
                                         node_size_field='degree',
                                         edge_label_field='type',
                                         edge_width=5, 
                                         edge_arrow_to=True,
                                         edge_color_highlight='#8A324E',
                                         edge_color_hover='red',
                                         graph_id=0)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"id": "REG0-12735", "x": -444.93258826499823, "y": -283.9145137244837, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12735"}, {"id": "pnp", "x": -503.8940632365483, "y": -368.4408446472762, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "pnp"}, {"id": "REG0-12365", "x": -441.6498861335582, "y": 1097.7085222563967, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12365"}, {"id": "rluD", "x": -372.47876331112866, "y": 1022.1597614707239, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "rluD"}, {"id": "REG0-12171", "x": 986.3275778339096, "y": -268.3471523819625, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12171"}, {"id": "ribB", "x": 940.6509773863174, "y": -360.01377791807374, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "ribB"}, {"id": "REG0-11885", "x": 1163.5356959271573, "y": 336.7752053860738, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11885"}, {"id": "gdhA", "x": 1182.2617361371354, "y": 239.22522940577576, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "gdhA"}, {"id": "REG0-11857", "x": -943.960540506923, "y": 708.5233616054004, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11857"}, {"id": "cirA", "x": -850.8677593276957, "y": 757.272177504319, "degree": 2, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "cirA"}, {"id": "REG0-11856", "x": -826.117978410631, "y": 859.5691083879537, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11856"}, {"id": "REG0-11875", "x": 313.80148210507764, "y": -178.8289378485632, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11875"}, {"id": "gss", "x": 243.7829359578298, "y": -259.8736074427582, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "gss"}, {"id": "REG0-11864", "x": 107.219555768873, "y": -900.3633067867429, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11864"}, {"id": "srlA", "x": 99.44152980956603, "y": -797.7205281446302, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "srlA"}, {"id": "REG0-10916", "x": -200.05534023103195, "y": 492.35845394463024, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-10916"}, {"id": "manX", "x": -268.7498157816375, "y": 410.963400003533, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "manX"}, {"id": "REG0-12201", "x": 42.037922783657336, "y": -9.237943723878594, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12201"}, {"id": "mprA", "x": 48.27386432164694, "y": -114.6741381537795, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "mprA"}, {"id": "REG0-11994", "x": 660.0448129702262, "y": -631.7322124607595, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11994"}, {"id": "chbC", "x": 759.7215536371947, "y": -611.42030808933, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "chbC"}, {"id": "REG0-11877", "x": -387.674984930151, "y": -583.1896630665543, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11877"}, {"id": "ascF", "x": -488.9547864234976, "y": -603.4310644104983, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "ascF"}, {"id": "REG0-12754", "x": -596.0553602588197, "y": 737.3816533967952, "degree": 1, "node_shap ...

# %%
df2 = bnv.query_graph(graph, source="gene", edge="PRODUCT")

# %%
df3 = pd.concat([df, df2])

# %%
g3 = ig.Graph.TupleList(df3.values, directed=True, edge_attrs="type")

# %%
nodes_dict3, edges_dict3 = bnv.prepare_plot_igraph(g3, scale=10)

# %%
# plot network
visJS2jupyter.visJS_module.visjs_network(nodes_dict3,
                                         edges_dict3, 
                                         node_size_multiplier=30,
                                         node_size_field='degree',
                                         edge_label_field='type',
                                         edge_width=5, 
                                         edge_color='type',
                                         edge_arrow_to=True,
                                         edge_color_highlight='#8A324E',
                                         edge_color_hover='red',
                                         graph_id=1)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"id": "REG0-12735", "x": -4270.504372963273, "y": 2337.4065323509567, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12735"}, {"id": "pnp", "x": -4484.577793936057, "y": 2373.476810714658, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "pnp"}, {"id": "REG0-12365", "x": -1709.0336752169128, "y": 4638.368999213393, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12365"}, {"id": "rluD", "x": -1497.9548734644802, "y": 4674.334903238319, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "rluD"}, {"id": "REG0-12171", "x": -2620.8486686895462, "y": -4557.1865540400895, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12171"}, {"id": "ribB", "x": -2813.316432245869, "y": -4470.690415631598, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "ribB"}, {"id": "REG0-11885", "x": 690.6231103368743, "y": 5768.5355029314815, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11885"}, {"id": "gdhA", "x": 695.9937451876274, "y": 5978.379887292751, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "gdhA"}, {"id": "REG0-11857", "x": -834.7468696199945, "y": 36.65912700730488, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11857"}, {"id": "cirA", "x": -654.3028319417917, "y": -112.37142811703788, "degree": 2, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "cirA"}, {"id": "REG0-11856", "x": -418.32761296384143, "y": -113.27347596988174, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11856"}, {"id": "REG0-11875", "x": 4940.784181185465, "y": 679.5990290793442, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11875"}, {"id": "gss", "x": 5049.043186239589, "y": 868.2862155908152, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "gss"}, {"id": "REG0-11864", "x": 4806.64971588685, "y": -832.0118513248392, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11864"}, {"id": "srlA", "x": 4924.032437504581, "y": -649.0711028313201, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "srlA"}, {"id": "REG0-10916", "x": -1129.4715248338669, "y": 4855.148879510159, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-10916"}, {"id": "manX", "x": -913.4638928929332, "y": 4814.552124206366, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "manX"}, {"id": "REG0-12201", "x": 2186.086391901989, "y": -3745.2282308851036, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12201"}, {"id": "mprA", "x": 2303.758300476532, "y": -3559.504187021582, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "mprA"}, {"id": "REG0-11994", "x": 2575.0292695325734, "y": 4801.916204783321, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11994"}, {"id": "chbC", "x": 2482.8257113611176, "y": 4603.030434332257, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "chbC"}, {"id": "REG0-11877", "x": 948.602006903868, "y": 1648.409752358838, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11877"}, {"id": "ascF", "x": 1167.8127751493175, "y": 1599.1405980514676, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "ascF"}, {"id": "REG0-12754", "x": 2928.701739270925, "y": -993.7894094904066, "degree": 1, "node_s ...
