# %%
# %matplotlib inline

# %% [markdown]
# # EcoCyc neo4j graph
#
# Description here

# %% [markdown]
# ## Load modules
#
#    * [pandas](https://pandas.pydata.org/)
#    * [python-igraph](http://igraph.org/python/)
#    * [py2neo](http://py2neo.org)
#    * [visJS2jupyter](https://ucsd-ccbb.github.io/visJS2jupyter/)

# %%
import pandas as pd
import igraph as ig
from py2neo import Graph, Node, Relationship
import visJS2jupyter.visJS_module

# %% [markdown]
# The following module is a custom script in [here]

# %%
import biocyc_neo4j_viz as bnv

# %% [markdown]
# ## Access the graph
# See http://localhost:7474/browser/ for the neo4j interface.

# %%
graph = Graph(host="neo4j")

# %% [markdown]
# ## Query graph
#
# The graph can be queried in three ways:
#
# ### 1. py2neo
#
#
# ### 2. CYPHER
#
#
# ### 3. bnv

# %%
# Using CYPHER
a = graph.run("MATCH (a) WHERE a.name={x} RETURN a.id", x='3_ISOPROPYLMALDEHYDROG_CPLX').evaluate()
a
# Out:
# '3_ISOPROPYLMALDEHYDROG_CPLX'

# %%
# Using bnv
df = bnv.query_graph(graph, target="gene", edge="REGULATES")

# %%
print( df.shape)
df.head()
# Out:
# (77, 3)
#        source target       type
# 0  REG0-12735    pnp  REGULATES
# 1  REG0-12365   rluD  REGULATES
# 2  REG0-12171   ribB  REGULATES
# 3  REG0-11885   gdhA  REGULATES
# 4  REG0-11857   cirA  REGULATES

# %% [markdown]
# ## Turn a query result into an igraph graph

# %%
g = ig.Graph.TupleList(df.values, directed=True, edge_attrs="type")

# %%
g.vcount()
# Out:
# 144

# %% [markdown]
# ## Visualize using visJS2jupyter

# %%
nodes_dict, edges_dict = bnv.prepare_plot_igraph(g, scale=10)

# %%
# plot network
visJS2jupyter.visJS_module.visjs_network(nodes_dict,
                                         edges_dict, 
                                         node_size_multiplier=30,
                                         node_size_field='degree',
                                         edge_label_field='type',
                                         edge_width=5, 
                                         edge_arrow_to=True,
                                         edge_color_highlight='#8A324E',
                                         edge_color_hover='red',
                                         graph_id=0)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"id": "REG0-12735", "x": 375.5725914207733, "y": -1235.3239842737194, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12735"}, {"id": "pnp", "x": 283.4439210494863, "y": -1275.2520681430583, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "pnp"}, {"id": "REG0-12365", "x": 334.4821312383733, "y": -540.3400594866798, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12365"}, {"id": "rluD", "x": 360.8157735678943, "y": -642.8733510019674, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "rluD"}, {"id": "REG0-12171", "x": 112.97562296825598, "y": 910.1055451798494, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12171"}, {"id": "ribB", "x": 50.10263621053902, "y": 990.5462212430868, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "ribB"}, {"id": "REG0-11885", "x": 370.9203357486593, "y": 673.4794618945658, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11885"}, {"id": "gdhA", "x": 318.9176638531081, "y": 768.8118549890216, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "gdhA"}, {"id": "REG0-11857", "x": -104.68981619317435, "y": 256.66196573949503, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11857"}, {"id": "cirA", "x": -218.95368006264908, "y": 256.03979330259824, "degree": 2, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "cirA"}, {"id": "REG0-11856", "x": -327.54856042122213, "y": 283.37356047473685, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11856"}, {"id": "REG0-11875", "x": -1039.2831614331296, "y": -408.3512407262734, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11875"}, {"id": "gss", "x": -1019.8448103367623, "y": -307.5558902928578, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "gss"}, {"id": "REG0-11864", "x": -87.86658862503538, "y": -1059.3433205072915, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11864"}, {"id": "srlA", "x": -190.0475017957639, "y": -1072.986208539301, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "srlA"}, {"id": "REG0-10916", "x": -806.6562653071176, "y": 182.0112639579023, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-10916"}, {"id": "manX", "x": -788.0616877925553, "y": 284.8852083624256, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "manX"}, {"id": "REG0-12201", "x": 336.8147524514717, "y": 266.72854465899843, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12201"}, {"id": "mprA", "x": 232.91925672048944, "y": 291.71518745659023, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "mprA"}, {"id": "REG0-11994", "x": 797.0120080776518, "y": 293.39437684107224, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11994"}, {"id": "chbC", "x": 879.9009836201674, "y": 231.12736452583397, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "chbC"}, {"id": "REG0-11877", "x": -801.6890536951823, "y": -401.34018673589566, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11877"}, {"id": "ascF", "x": -871.6180997039327, "y": -479.0645891839501, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "ascF"}, {"id": "REG0-12754", "x": -327.02334151883434, "y": 756.832441407708, "degree": 1,  ...

# %%
df2 = eco.query_graph(graph, source="gene", edge="PRODUCT")

# %%
df3 = pd.concat([df, df2])

# %%
g3 = ig.Graph.TupleList(df3.values, directed=True, edge_attrs="type")

# %%
nodes_dict3, edges_dict3 = bnv.prepare_plot_igraph(g3, scale=10)

# %%
# plot network
visJS2jupyter.visJS_module.visjs_network(nodes_dict3,
                                         edges_dict3, 
                                         node_size_multiplier=30,
                                         node_size_field='degree',
                                         edge_label_field='type',
                                         edge_width=5, 
                                         edge_color='type',
                                         edge_arrow_to=True,
                                         edge_color_highlight='#8A324E',
                                         edge_color_hover='red',
                                         graph_id=1)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"id": "REG0-12735", "x": -3513.451378424824, "y": 2436.9302638134996, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12735"}, {"id": "pnp", "x": -3579.5822673302514, "y": 2642.2998253618493, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "pnp"}, {"id": "REG0-12365", "x": 4116.292214005118, "y": -1961.9184942628103, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12365"}, {"id": "rluD", "x": 4073.770938950135, "y": -2174.2577263277262, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "rluD"}, {"id": "REG0-12171", "x": -646.0068285963786, "y": -5911.64116301149, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12171"}, {"id": "ribB", "x": -634.7369604802825, "y": -5700.513070521756, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "ribB"}, {"id": "REG0-11885", "x": -1632.437108461615, "y": 4454.797759459821, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11885"}, {"id": "gdhA", "x": -1819.5303754215406, "y": 4562.936555212413, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "gdhA"}, {"id": "REG0-11857", "x": 41.53572972840838, "y": -1516.4678106593476, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11857"}, {"id": "cirA", "x": 215.60092450478177, "y": -1355.4989976423535, "degree": 2, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "cirA"}, {"id": "REG0-11856", "x": 390.44852014875977, "y": -1191.35067018611, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11856"}, {"id": "REG0-11875", "x": -2109.0614348153254, "y": 4879.638344168515, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11875"}, {"id": "gss", "x": -2277.052104403595, "y": 4750.501990260895, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "gss"}, {"id": "REG0-11864", "x": -4737.3529830356965, "y": 1970.7336595669983, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11864"}, {"id": "srlA", "x": -4783.105795008024, "y": 1752.2853278812804, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "srlA"}, {"id": "REG0-10916", "x": 881.6184484169638, "y": 2735.107958713865, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-10916"}, {"id": "manX", "x": 832.355057849411, "y": 2517.5666648831, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "manX"}, {"id": "REG0-12201", "x": -1655.3176368324634, "y": 2234.5643672801793, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-12201"}, {"id": "mprA", "x": -1460.5079577750996, "y": 2349.8351712188833, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "mprA"}, {"id": "REG0-11994", "x": 1301.082451216782, "y": 1763.933970750813, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11994"}, {"id": "chbC", "x": 1082.8271827396643, "y": 1721.759929808213, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "chbC"}, {"id": "REG0-11877", "x": 1719.433707623889, "y": -5297.159519998277, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "REG0-11877"}, {"id": "ascF", "x": 1936.1407747643786, "y": -5281.266280344743, "degree": 1, "node_shape": "dot", "color": "#8BA8D3", "border_width": 0, "title": "ascF"}, {"id": "REG0-12754", "x": -4271.056573143386, "y": 1618.1348435180942, "degree": 1, "n ...
